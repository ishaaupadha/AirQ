# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/air_quality_data.csv")

# %%
df.head()
# Out:
#              timestamp  PM2.5  PM10  NO2        CO  temperature   humidity  \
# 0  2022-01-01 00:00:00    112   166   32  2.646146    23.927153  53.232361
# 1  2022-01-01 01:00:00    280   235   69  3.908886    22.486996  45.056573
# 2  2022-01-01 02:00:00    116   393   74  3.569799    39.465230  80.733892
# 3  2022-01-01 03:00:00     81   340   46  2.900238     5.612772  30.044818
# 4  2022-01-01 04:00:00    198   322  165  3.322831    19.511878  88.862373
#
#    wind_speed  precipitation  traffic_volume  AQI
# 0    5.330958              0             770  137
# 1    3.636638              0            2580  259
# 2    3.049317              0            4698  222
# 3    4.436238              0            1460  178
# 4    8.365376              0             524  253

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26305 entries, 0 to 26304
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       26305 non-null  object
#  1   PM2.5           26305 non-null  int64
#  2   PM10            26305 non-null  int64
#  3   NO2             26305 non-null  int64
#  4   CO              26305 non-null  float64
#  5   temperature     26305 non-null  float64
#  6   humidity        26305 non-null  float64
#  7   wind_speed      26305 non-null  float64
#  8   precipitation   26305 non-null  int64
#  9   traffic_volume  26305 non-null  int64
#  10  AQI             26305 non-null  int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 2.2+ MB

# %%
df.isnull().sum()
# Out:
# timestamp         0
# PM2.5             0
# PM10              0
# NO2               0
# CO                0
# temperature       0
# humidity          0
# wind_speed        0
# precipitation     0
# traffic_volume    0
# AQI               0
# dtype: int64

# %%
df.describe()
# Out:
#               PM2.5          PM10           NO2            CO   temperature  \
# count  26305.000000  26305.000000  26305.000000  26305.000000  26305.000000
# mean     153.944231    208.874967    101.990116      2.556707     22.440930
# std       83.827387    109.980087     56.209455      1.409349     10.116407
# min       10.000000     20.000000      5.000000      0.100230      5.001027
# 25%       81.000000    113.000000     53.000000      1.338792     13.553754
# 50%      154.000000    209.000000    102.000000      2.567042     22.511133
# 75%      227.000000    304.000000    151.000000      3.785227     31.200430
# max      299.000000    399.000000    199.000000      4.999388     39.999721
#
#            humidity    wind_speed  precipitation  traffic_volume           AQI
# count  26305.000000  26305.000000   26305.000000    26305.000000  26305.000000
# mean      54.914737      5.037554       0.051435     2554.739403    180.004220
# std       20.250755      2.888976       0.220888     1418.151534     55.772971
# min       20.001927      0.000066       0.000000      100.000000     25.000000
# 25%       37.350440      2.526506       0.000000     1326.000000    139.000000
# 50%       54.826736      5.048301       0.000000     2555.000000    180.000000
# 75%       72.433271      7.542275       0.000000     3780.000000    220.000000
# max       89.994491      9.999894       1.000000     4999.000000    333.000000

# %%
sns.histplot(df["AQI"])
plt.plot()
# Out:
# []

# %%
df.head()
# Out:
#              timestamp  PM2.5  PM10  NO2        CO  temperature   humidity  \
# 0  2022-01-01 00:00:00    112   166   32  2.646146    23.927153  53.232361
# 1  2022-01-01 01:00:00    280   235   69  3.908886    22.486996  45.056573
# 2  2022-01-01 02:00:00    116   393   74  3.569799    39.465230  80.733892
# 3  2022-01-01 03:00:00     81   340   46  2.900238     5.612772  30.044818
# 4  2022-01-01 04:00:00    198   322  165  3.322831    19.511878  88.862373
#
#    wind_speed  precipitation  traffic_volume  AQI
# 0    5.330958              0             770  137
# 1    3.636638              0            2580  259
# 2    3.049317              0            4698  222
# 3    4.436238              0            1460  178
# 4    8.365376              0             524  253

# %%
df.drop(columns=["timestamp"],inplace=True)
df.head()
# Out:
#    PM2.5  PM10  NO2        CO  temperature   humidity  wind_speed  \
# 0    112   166   32  2.646146    23.927153  53.232361    5.330958
# 1    280   235   69  3.908886    22.486996  45.056573    3.636638
# 2    116   393   74  3.569799    39.465230  80.733892    3.049317
# 3     81   340   46  2.900238     5.612772  30.044818    4.436238
# 4    198   322  165  3.322831    19.511878  88.862373    8.365376
#
#    precipitation  traffic_volume  AQI
# 0              0             770  137
# 1              0            2580  259
# 2              0            4698  222
# 3              0            1460  178
# 4              0             524  253

# %%
x=df.iloc[:,0:9]
x
# Out:
#        PM2.5  PM10  NO2        CO  temperature   humidity  wind_speed  \
# 0        112   166   32  2.646146    23.927153  53.232361    5.330958
# 1        280   235   69  3.908886    22.486996  45.056573    3.636638
# 2        116   393   74  3.569799    39.465230  80.733892    3.049317
# 3         81   340   46  2.900238     5.612772  30.044818    4.436238
# 4        198   322  165  3.322831    19.511878  88.862373    8.365376
# ...      ...   ...  ...       ...          ...        ...         ...
# 26300     83    73   83  2.704773    19.694176  31.513612    6.949180
# 26301     69   307  175  2.933871    12.477994  76.788559    4.741276
# 26302    131   303   42  4.054122    10.275454  58.606000    3.348568
# 26303    212   105  196  2.115305    34.222209  40.131707    0.001727
# 26304     20    64   41  3.389049    15.056096  53.538310    5.969552
#
#        precipitation  traffic_volume
# 0                  0             770
# 1                  0            2580
# 2                  0            4698
# 3                  0            1460
# 4                  0             524
# ...              ...             ...
# 26300              0            1419
# 26301              0            2802
# 26302              0             693
# 26303              0             691
# 26304              0            1703
#
# [26305 rows x 9 columns]

# %%
y= df["AQI"]
y
# Out:
# 0        137
# 1        259
# 2        222
# 3        178
# 4        253
#         ...
# 26300    102
# 26301    182
# 26302    203
# 26303    188
# 26304     69
# Name: AQI, Length: 26305, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred=model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error,r2_score
mae = mean_absolute_error(ytest, ypred)
r2 = r2_score(ytest, ypred)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 0.24908254411470307
# R-squared: 0.9999733944033158
